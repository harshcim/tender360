# %%
import pandas as pd

# %%
data = pd.read_excel("/home/cimcon/Desktop/Tender Usecases/Data/BOQ/BOQ_436332.xls")

# %%
data.head(20)
# Out:
#                                        Percentage BoQ  \
# 0                                          BoQ_Ver3.0
# 1                Select, At Par, Excess (+), Less (-)
# 2   Tender Inviting Authority: Nagar Parisad Kakra...
# 3   Name of Work: Work of Augmentation of Water Su...
# 4                Contract No:  UAD/1216/Kakrahti/2024
# 5
# 6        Name of the Bidder/ Bidding Firm / Company :
# 7   PRICE SCHEDULE\n(This BOQ template must not be...
# 8                                            NUMBER #
# 9                                            Sl.\nNo.
# 10                                                  1
# 11                                                  1
# 12                                                  2
# 13                                   Total in Figures
# 14                             Quoted Rate in Figures
# 15                               Quoted Rate in Words
#
#                                            Unnamed: 1  \
# ...

# %%
data_1 = pd.read_csv("/home/cimcon/Desktop/Tender Usecases/Tender360/practice ipynb/processed_data.csv")

# %%
data_1.head(25)
# Out:
#                  Sl.\nNo.                                   Item Description  \
# 0                       1                                                  2
# 1                       1  Work of Augmentation of Water Supply System of...
# 2                       2                                Total tender Value
# 3        Total in Figures                                                NaN
# 4  Quoted Rate in Figures                                                NaN
# 5    Quoted Rate in Words                                                NaN
#
#    Quantity   Units
# 0       4.0       5
# 1       NaN     NaN
# 2       1.0     Nos
# 3       NaN     NaN
# 4       NaN  Select
# 5       NaN     NaN
